# %% [markdown]
# ![Data Dunkers Banner](https://github.com/Data-Dunkers/lessons/blob/main/images/top-banner.jpg?raw=true)
#
# <a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FData-Dunkers%2Factivities&branch=main&subPath=data-from-excel.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/Data-Dunkers/lessons/main/images/open-in-callysto-button.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>
# <a href="https://colab.research.google.com/github/Data-Dunkers/activities/blob/main/data-from-excel.ipynb" target="_parent"><img src="https://raw.githubusercontent.com/Data-Dunkers/lessons/main/images/open-in-colab-button.svg?sanitize=true" width="123" height="24" alt="Open in Colab"/></a>

# %% [markdown]
# # Data Dunkers Activity Notebook: Data from an Excel File

# %% [markdown]
# The corresponding lesson notebook for this activity notebook can be found [here](https://github.com/pbeens/Data-Dunkers/blob/main/Demos/data-from-excel.ipynb).

# %% [markdown]
# # Objectives

# %% [markdown]
# Students will be able to:
#
# - Retrieve data from an Excel file.
# - Understand the basic steps to prepare and visualize data.
# - Recognize the similarities and differences between working with CSV and Excel files.

# %% [markdown]
# # Setup

# %%
# Only if necessary

# %pip install pandas -q
# %pip install plotly.express -q
# %pip install openpyxl -q

# %% [markdown]
# # Import / Input

# %%
# import plotly.express and pandas
import plotly.express as px
import pandas as pd

# Read the Excel file into a DataFrame named df
url = 'https://raw.githubusercontent.com/pbeens/Data-Dunkers/main/Data/x-y-data.xlsx'
df = pd.read_excel(url)

# %% [markdown]
# # Output

# %%
# Create the plot
# This code is the same as the CSV example!

fig = px.line(data_frame=df,
              x='X',
              y='Y',
              title='Data from a CSV file')

# Show the plot
fig.show()

# %% [markdown]
# # Exercise

# %%
# Put it all together in one cell

# Setup


# Input


# Process (not necessary!)


# Output
