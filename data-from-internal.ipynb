# %% [markdown]
# ![Data Dunkers Banner](https://github.com/Data-Dunkers/lessons/blob/main/images/top-banner.jpg?raw=true)
#
# <a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FData-Dunkers%2Factivities&branch=main&subPath=data-from-internal.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/Data-Dunkers/lessons/main/images/open-in-callysto-button.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>
# <a href="https://colab.research.google.com/github/Data-Dunkers/activities/blob/main/data-from-internal.ipynb" target="_parent"><img src="https://raw.githubusercontent.com/Data-Dunkers/lessons/main/images/open-in-colab-button.svg?sanitize=true" width="123" height="24" alt="Open in Colab"/></a>

# %% [markdown]
# # Data Dunkers Activity Notebook: Data from Within the Notebook

# %% [markdown]
# The corresponding lesson notebook for this activity notebook can be found [here](https://github.com/pbeens/Data-Dunkers/blob/main/Demos/data-from-internal.ipynb).

# %% [markdown]
# # Objectives

# %% [markdown]
# Students will be able to:
#
# - Sort data in a DataFrame based on specific columns.
# - Understand the impact of sorting data in ascending vs. descending order.
# - Apply multiple sorting criteria to organize data more effectively.

# %% [markdown]
# # Import

# %%
import plotly.express as px

# %% [markdown]
# # Input

# %% [markdown]
# Define the data (in two variables).

# %%
x_data = [0, 1, 2, 3, 4, 5]
y_data = [0, 1, 4, 9, 16, 25]

# %% [markdown]
# # Output

# %% [markdown]
# Create the line plot using those two variables.

# %%
px.line(x=x_data, y=y_data, title='X vs Y Plot')

# %% [markdown]
# # Exercise 1

# %% [markdown]
# Copy all the code into one cell, paying attention to what goes into each section.

# %%
# Setup


# Input


# Process


# Output

# %% [markdown]
# # Exercise 2

# %% [markdown]
# The variables `year` and `FGM` will be Pascal Siakam's "Field Goals Made" results while he was with the Toronto Raptors. Write code that plots a line graph of this data.

# %%
# Setup


# Input
year = ['2016-17', '2017-18', '2018-19', '2019-20', '2020-21', '2021-22', '2022-23']
FGM = [103, 253, 519, 500, 437, 596, 630]

# Output
