# %% [markdown]
# <a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FData-Dunkers%2Factivities&branch=main&subPath=data-filtering.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/Data-Dunkers/lessons/main/images/open-in-callysto-button.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>
# <a href="https://colab.research.google.com/github/Data-Dunkers/activities/blob/main/data-filtering.ipynb" target="_parent"><img src="https://raw.githubusercontent.com/Data-Dunkers/lessons/main/images/open-in-colab-button.svg?sanitize=true" width="123" height="24" alt="Open in Colab"/></a>

# %% [markdown]
# # Data Dunkers Activity Notebook: Filtering Data

# %% [markdown]
# The corresponding lesson notebook for this activity notebook can be found [here](https://github.com/pbeens/Data-Dunkers/blob/main/Demos/filtering-data.ipynb).

# %% [markdown]
# # Objectives

# %% [markdown]
# Students will be able to:
#
# - Learn how to filter data to focus on what’s important.
# - Understand the process of refining data for better analysis.
# - Apply simple techniques to clean and prepare data for use.

# %% [markdown]
# # Setup

# %%
# Only if necessary

# %pip install plotly.express -q

# %% [markdown]
# # Import / Input

# %%
import pandas as pd

# URL of the CSV file containing data for Pascal Siakam
url = 'https://raw.githubusercontent.com/pbeens/Data-Dunkers/main/Data/Pascal_Siakam.csv'

# Read the CSV file into a pandas DataFrame named df
df = pd.read_csv(url)

# Display the DataFrame
display(df)

# %% [markdown]
# # Process

# %%
# Drop the index 9 row, then display the updated dataframe

df = df.drop(9)
display(df)

# %% [markdown]
# ![](https://raw.githubusercontent.com/pbeens/Images/main/other/dd-presentation/filter_by_season.png)

# %%
# Filter the DataFrame to exclude seasons after 2022-23
filter = df['SEASON_ID'] <= '2022-23'
df = df[filter]

# Display the updated dataframe
display(df)

# %%
# Apply a compound filter
# Q. Does this filter update the dataframe?

filter_1 = df['FT_PCT'] > 0.75  # free throw % above 75%
filter_2 = df['GS'] == df['GP']  # games started equals games played

# Display the filtered content
display(df[filter_1 & filter_2])

# %% [markdown]
# ## Boolean Operators
#
# ![](https://raw.githubusercontent.com/pbeens/Images/main/other/dd-presentation/filter_operators.png)

# %% [markdown]
# # Exercise

# %% [markdown]
# In the cell below, update the program to display only rows where Assists ('AST') were greater than 200 **or** Steals ('STL') were greater than 50.

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/pbeens/Data-Dunkers/main/Data/Pascal_Siakam.csv'

df = pd.read_csv(url)

# Filter the DataFrame to exclude seasons after 2022-23
df = df[df['SEASON_ID'] <= '2022-23']

# filter_1 =
# filter_2 =
display(df)
