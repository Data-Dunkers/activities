# %% [markdown]
# <a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FData-Dunkers%2Factivities&branch=main&subPath=data-from-webpage.ipynb&depth=1" target="_blank"><img src="https://raw.githubusercontent.com/Data-Dunkers/lessons/main/images/open-in-callysto-button.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"></a>
# <a href="https://colab.research.google.com/github/Data-Dunkers/activities/blob/main/data-from-webpage.ipynb" target="_blank"><img src="https://raw.githubusercontent.com/Data-Dunkers/lessons/main/images/open-in-colab-button.svg?sanitize=true" width="123" height="24" alt="Open in Colab"></a>

# %% [markdown]
# # Data Dunkers Activity Notebook: Data from a Webpage

# %% [markdown]
# The corresponding lesson notebook for this activity notebook can be found [here](https://github.com/pbeens/Data-Dunkers/blob/main/Demos/data-from-webpage.ipynb).

# %% [markdown]
# # Objectives

# %% [markdown]
# Students will be able to:
#
# - Explore how to extract and use data from a webpage.
# - Learn to select and visualize specific data from web sources.

# %% [markdown]
# # Setup

# %%
# Only if necessary

# %pip install pandas -q
# %pip install plotly_express -q
# %pip install lxml -q
# %pip install html5lib -q

# %% [markdown]
# # Import / Input

# %%
# import plotly.express and pandas
import plotly.express as px
import pandas as pd

# Read the html file into a DataFrame named df
# Note we are using the first table which is index 0
url = 'https://raw.githubusercontent.com/pbeens/Data-Dunkers/main/Data/x-y-data.html'
df = pd.read_html(url)[0]  # Index 0 is the first table

# %% [markdown]
# # Output

# %% [markdown]
# Formatting of the plot is the same as in previous lessons. If you need a hint, refer to the [CSV stub](https://colab.research.google.com/drive/1bW33Yva8Xl7GUvqs-SgPpyGndxpsnTOH#scrollTo=DXW3Qu4_HFwb).

# %%
# Create the plot
# This code is the same as the CSV example!

fig = px.line(data_frame=df,
              x='X',
              y='Y',
              title='Data from a CSV file')

# Show the plot
fig.show()

# %% [markdown]
# # Exercise

# %% [markdown]
# Enter all the code to plot the Excel data.

# %%
# Put it all together in one cell
# Setup


# Input


# Process (not necessary!)


# Output
