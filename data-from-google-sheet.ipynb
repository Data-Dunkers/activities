# %% [markdown]
# ![Data Dunkers Banner](https://github.com/Data-Dunkers/lessons/blob/main/images/top-banner.jpg?raw=true)
#
# <a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FData-Dunkers%2Factivities&branch=main&subPath=data-from-google-sheet.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/Data-Dunkers/lessons/main/images/open-in-callysto-button.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>
# <a href="https://colab.research.google.com/github/Data-Dunkers/activities/blob/main/data-from-google-sheet.ipynb" target="_parent"><img src="https://raw.githubusercontent.com/Data-Dunkers/lessons/main/images/open-in-colab-button.svg?sanitize=true" width="123" height="24" alt="Open in Colab"/></a>

# %% [markdown]
# # Data Dunkers Activity Notebook: Data from a Google Sheet

# %% [markdown]
# The corresponding lesson notebook for this activity notebook can be found [here](https://github.com/pbeens/Data-Dunkers/blob/main/Demos/data-from-google-sheet.ipynb).

# %% [markdown]
# # Objectives

# %% [markdown]
# Students will be able to:
#
# - Discover how to access and use data from a Google Sheet.
# - Recognize the similarities and differences between working with CSV and Google Sheets.

# %% [markdown]
# # Setup / Import / Input

# %%
# Only if necessary

# %pip install pandas -q
# %pip install plotly.express -q
# %pip install openpyxl -q

# %%
# import plotly.express and pandas
import pandas as pd
import plotly.express as px
# import

# Google Sheet URL variable, with modified /export?format=csv ending
url = 'https://docs.google.com/spreadsheets/d/1ZULKhYzsMd4eYwiprsyGgE9Df3gaVtO8WRalUQDn-xE/export?format=csv'

# Read the Google Sheet into a DataFrame named df
# Note we are using the url variable
# It gets treat like a CSV file!
df = pd.read_csv(url)

# %% [markdown]
# # Output

# %%
# Create the plot
# This code is the same as the CSV example!

fig = px.line(data_frame=df,
              x='X',
              y='Y',
              title='Data from a CSV file')

# Show the plot
fig.show()

# %% [markdown]
# # Exercise

# %%
# Put it all together in one cell

# Setup


# Input


# Process (not necessary!)


# Output
